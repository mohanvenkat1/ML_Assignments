# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanvenkat1/ML_Assignments/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/SOCR-HeightWeight.csv")
df.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Index           25000 non-null  int64
#  1   Height(Inches)  25000 non-null  float64
#  2   Weight(Pounds)  25000 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 586.1 KB

# %%
df=df.drop(columns='Index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-a7d510e3f99e> in <cell line: 1>()
# ----> 1 df=df.drop(columns='Index')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df
# Out:
#        Height(Inches)  Weight(Pounds)
# 0            65.78331        112.9925
# 1            71.51521        136.4873
# 2            69.39874        153.0269
# 3            68.21660        142.3354
# 4            67.78781        144.2971
# ...               ...             ...
# 24995        69.50215        118.0312
# 24996        64.54826        120.1932
# 24997        64.69855        118.2655
# 24998        67.52918        132.2682
# 24999        68.87761        124.8742
#
# [25000 rows x 2 columns]

# %%
df.head(5)
# Out:
#    Height(Inches)  Weight(Pounds)
# 0        65.78331        112.9925
# 1        71.51521        136.4873
# 2        69.39874        153.0269
# 3        68.21660        142.3354
# 4        67.78781        144.2971

# %%
df.shape
# Out:
# (25000, 2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.scatter(df["Weight(Pounds)"],df["Height(Inches)"])

# %%
df.corr()
# Out:
#                 Height(Inches)  Weight(Pounds)
# Height(Inches)        1.000000        0.502859
# Weight(Pounds)        0.502859        1.000000

# %%
sns.pairplot(df)

# %%
for col in df.columns:
    sns.boxplot(
        data = df,
        x = df[col]
    )
    plt.show()

# %%
sns.scatterplot(
    x='Height(Inches)',
    y='Weight(Pounds)',
    data=df
)
plt.xlim(62, 74)
plt.ylim(95, 159)
plt.show()

# %%
plt.subplot(1, 2, 1)
plt.hist(df['Height(Inches)'], bins=30, color='blue', edgecolor='black')
plt.title('Histogram of Height')
plt.xlabel('Height')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# OBSERVATION :
#                 The dataset showed a normal distribution for both heights and weights, with a clear positive correlation between them. Data preprocessing and visualization helped identify trends and outliers, ensuring a clean and reliable dataset for analysis.

# %% [markdown]
# conculsion :
#
#             The weights and heights dataset analysis revealed a positive linear relationship, with taller individuals generally having higher weights. A regression model effectively predicted weight based on height, highlighting the dataset's utility for practical applications like health assessments. Proper preprocessing and visualization were key to deriving insights.
